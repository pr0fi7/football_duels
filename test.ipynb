# %%
# !pip install ultralytics
# !pip install tracker
import cv2
import numpy as np
from ultralytics import YOLO
# from tracker import SORT  # or any other tracker

# %%
# Check if model weights exist, if not, download them
model_weights = 'yolov8m.pt'

# Initialize YOLO model with the weights
model = YOLO(model_weights)

# Run the model on the video
results = model.predict('data/test_10sec.mp4', save=True)

# Process the results
print(results[0])
print("====================")
for box in results[0].boxes:
    print(box)

# while video.isOpened():
#     ret, frame = video.read()
#     if not ret:
#         break

#     # Detect players
#     boxes, confidences, class_ids = yolo.detect(frame)

#     # Track players
#     tracked_objects = tracker.update(boxes)

#     # Check for collisions
#     for i, obj1 in enumerate(tracked_objects):
#         for j, obj2 in enumerate(tracked_objects):
#             if i != j:
#                 if bbox_overlap(obj1[:4], obj2[:4]):
#                     collision_frame = video.get(cv2.CAP_PROP_POS_FRAMES)
#                     collision_time = video.get(cv2.CAP_PROP_POS_MSEC)
#                     collision_location = get_collision_location(obj1[:4], obj2[:4])
#                     log_collision(collision_frame, collision_time, collision_location)

# video.release()
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/253) /Users/markshevchenkopu/Desktop/my_projects/personal_projects/football_duel/data/test_10sec.mp4: 192x640 7 persons, 268.1ms
# video 1/1 (frame 2/253) /Users/markshevchenkopu/Desktop/my_projects/personal_projects/football_duel/data/test_10sec.mp4: 192x640 6 persons, 272.2ms
# ...
